# %%
pip install scikit-image
# Out:
# ...
#
# ...

# %%
from skimage.feature import hog
from skimage import io, color, filters
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow

# %%
image1 = imread('C:/Users/Aslam/OneDrive/Pictures/pics fpr clg/4.jpg')
imshow(image1);

# %%
# Load and convert the image to grayscale
img = io.imread('C:/Users/Aslam/OneDrive/Pictures/pics fpr clg/4.jpg')
img_gray = color.rgb2gray(img)

# Extract HOG features
hog_features, hog_image = hog(image2, visualize=True)

# Visualize HOG image
plt.figure(figsize=(8, 4))
plt.subplot(121).imshow(image2, cmap=plt.cm.gray)
plt.title('Original Image')
plt.subplot(122).imshow(hog_image, cmap=plt.cm.gray)
plt.title('HOG Features')
plt.show()

# %%
image2 = imread('C:/Users/Aslam/OneDrive/Pictures/pics fpr clg/4.jpg', as_gray=True)
imshow(image2);

# %%
pixel_feat1 = np.reshape(image2, (900 * 900))
pixel_feat1
# Out:
# array([0.11772235, 0.11772235, 0.11772235, ..., 0.24354196, 0.24746353,
#        0.2513851 ])

# %%
pre_hor = filters.prewitt_h(image2)
pre_ver = filters.prewitt_v(image2)

# Display the horizontal and vertical edge detection results
plt.subplot(1, 2, 1)
plt.imshow(pre_hor, cmap='gray')
plt.title("Horizontal Edge Detection")

plt.subplot(1, 2, 2)
plt.imshow(pre_ver, cmap='gray')
plt.title("Vertical Edge Detection")

plt.show()
